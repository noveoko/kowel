# %%
data = [    {"name": "Heinrich GALINSKY", "birthdate": "29.01.1928", "country": "POLEN", "nickname": "Henri"},    {"name": "Johann GALINSKY", "birthdate": "15.02.1932", "country": "POLEN", "nickname": "Jean"},    {"name": "Josef GALINSKY", "birthdate": "27.12.1933", "country": "POLEN", "nickname": "Joseph"},    {"name": "Karl GALINSKY", "birthdate": "02.11.1937", "country": "POLEN", "nickname": "Charles"},    {"name": "Wolf GALINSKY", "birthdate": "27.05.1930", "country": "POLEN", "nickname": None}]

# %%
import re

def parse_document(document):
    parsed_data = []
    main_data = False
    
    for line in document.split('\n'):
        if main_data:
            current_record = re.match(r'([^\d]+)\s+(\d{2}\.\d{2}\.\d{4}|UNBEKANNT|e\s+ABELE)\s+(.+)', line)
            if current_record:
                surname_and_name, dob, nationality = current_record.groups()
                full_name = surname_and_name.strip()  # Store the full name string before parsing
                surname_and_name = surname_and_name.rsplit(' ', 1)
                
                if len(surname_and_name) == 2:
                    surname, name = surname_and_name[0], surname_and_name[1]
                else:
                    surname, name = surname_and_name[0], ''
                
                if name.startswith('('):
                    name = name[1:]
                
                parsed_data.append({
                    'surname': surname.strip().title(),
                    'name': [name.strip().title()],
                    'dob': dob.strip(),
                    'nationality': nationality.strip(),
                    'full_name': full_name  # Add the full name to the parsed_data dictionary
                })
            else:
                # Additional names
                current_name = re.match(r'\w+', line)
                if current_name and parsed_data:
                    parsed_data[-1]['name'].append(current_name.group().strip())
        
        if line.startswith("--------------------------------------------------------------------------------------------"):
            main_data = True

    return parsed_data

with open('raw_data.txt', 'r', encoding='utf-8') as f:
    raw_text = f.read()
    parsed = parse_document(raw_text)

# %%
for count, person in enumerate(parsed):
    if 'ewski' in person['full_name'].lower():
        print(person)
# Out:
# {'surname': 'Bartoszewski', 'name': ['Zenon'], 'dob': '01.10.1927', 'nationality': 'POLEN', 'full_name': 'BARTOSZEWSKI Zenon'}
# {'surname': 'Berkowicz-Rynarzewski', 'name': ['Else'], 'dob': '24.01.1914', 'nationality': 'STAATENLOS (POLEN)', 'full_name': 'BERKOWICZ-RYNARZEWSKI Else'}
# {'surname': 'Chmielewski', 'name': ['Irene'], 'dob': '02.08.1912', 'nationality': 'POLEN', 'full_name': 'CHMIELEWSKI IRENE'}
# {'surname': 'Chwaliszewski', 'name': ['Sabina'], 'dob': '03.06.1919', 'nationality': 'POLEN', 'full_name': 'CHWALISZEWSKI Sabina'}
# {'surname': 'Chwaliszewski', 'name': ['Zbigniew'], 'dob': '13.05.1906', 'nationality': 'POLEN', 'full_name': 'CHWALISZEWSKI Zbigniew'}
# {'surname': 'Cisinski-Miodoszewski', 'name': ['Rosa'], 'dob': '26.12.1908', 'nationality': 'POLEN', 'full_name': 'CISINSKI-MIODOSZEWSKI Rosa'}
# {'surname': 'Dluzniewski Jacques', 'name': ['Haim'], 'dob': '03.05.1932', 'nationality': 'FRANKREICH', 'full_name': 'DLUZNIEWSKI Jacques Haim'}
# {'surname': 'Dobrzelewski', 'name': ['Wladislaw'], 'dob': '05.07.1915', 'nationality': 'POLEN', 'full_name': 'DOBRZELEWSKI Wladislaw'}
# {'surname': 'Duchniewski', 'name': ['Stefan'], 'dob': '01.01.1917', 'nationality': 'POLEN', 'full_name': 'DUCHNIEWSKI Stefan'}
# {'surname': 'Furstenberg-Smoszewski Käthe', 'name': ['Ruth'], 'dob': '22.05.1913', 'nationality': 'NIEDERLANDE', 'full_name': 'FURSTENBERG-SMOSZEWSKI Käthe Ruth'}
# {'surname': 'Gajewski', 'name': ['Stefan'], 'dob': '25.01.1924', 'nationality': 'POLEN', 'full_name': 'GAJEWSKI Stefan'}
# {'surname': 'Goralewski', 'name': ['Onufry'], 'dob': '31.05.1924', 'nationality': 'POLEN', 'full_name': 'GORALEWSKI Onufry'}
# {'surname': 'Grudziewski', 'name': ['Helene'], 'dob': '02.04.1885', 'nationality': 'SCHWEIZ', 'full_name': 'GRUDZIEWSKI HELENE'}
# {'surname': 'Janiszewski', 'name': ['Maksymilian'], 'dob': '14.10.1917', 'nationality': 'POLEN', 'full_name': 'JANISZEWSKI Maksymilian'}
# {'surname': 'Kalinski-Kleczewski', 'name': ['Berta'], 'dob': '06.08.1908', 'nationality': 'POLEN', 'full_name': 'KALINSKI-KLECZEWSKI Berta'}
# {'surname': 'Kielczewski', 'name': ['Eugen'], 'dob': '30.03.1902', 'nationality': 'POLEN', 'full_name': 'KIELCZEWSKI Eugen'}
# {'surname': 'Kleczewski', 'name': ['Michel'], 'dob': '25.01.1910', 'nationality': 'POLEN', 'full_name': 'KLECZEWSKI Michel'}
# {'surname': 'Kleczewski', 'name': ['Pierrette'], 'dob': '08.10.1940', 'nationality': 'STAATENLOS (POLEN)', 'full_name': 'KLECZEWSKI PIerrette'}
# {'surname': 'Kleczewski-Gradsztejn', 'name': ['Bayla'], 'dob': '01.10.1911', 'nationality': 'POLEN', 'full_name': 'KLECZEWSKI-GRADSZTEJN Bayla'}
# {'surname': 'Kowalewski Janusz', 'name': ['Henryk'], 'dob': '04.01.1916', 'nationality': 'POLEN', 'full_name': 'KOWALEWSKI Janusz Henryk'}
# {'surname': 'Kulewski', 'name': ['Stefan'], 'dob': '01.01.1904', 'nationality': 'POLEN', 'full_name': 'KULEWSKI Stefan'}
# {'surname': 'Lesniewski', 'name': ['Tadeusz'], 'dob': '07.08.1920', 'nationality': 'POLEN', 'full_name': 'LESNIEWSKI Tadeusz'}
# {'surname': 'Markovics-Wasiliewski', 'name': ['Sara'], 'dob': '15.05.1907', 'nationality': 'UNGARN', 'full_name': 'MARKOVICS-WASILIEWSKI SARA'}
# {'surname': 'Matuszewski', 'name': ['Taddeusz'], 'dob': '06.11.1927', 'nationality': 'POLEN', 'full_name': 'MATUSZEWSKI TADDEUSZ'}
# {'surname': 'Milewski', 'name': ['Anton'], 'dob': '07.05.1900', 'nationality': 'LITAUEN', 'full_name': 'MILEWSKI Anton'}
# {'surname': 'Modrzewski', 'name': ['Charles'], 'dob': '27.10.1934', 'nationality': 'POLEN', 'full_name': 'MODRZEWSKI Charles'}
# {'surname': 'Modzejewski Alias Blaszka', 'name': ['Jacques'], 'dob': '02.08.1943', 'nationality': 'POLEN', 'full_name': 'MODZEJEWSKI ALIAS BLASZKA JACQUES'}
# {'surname': 'Modzejewski Nee Blaszka', 'name': ['Vera'], 'dob': '12.04.1925', 'nationality': 'POLEN', 'full_name': 'MODZEJEWSKI NEE BLASZKA VERA'}
# {'surname': 'Mozolewski', 'name': ['Kusma'], 'dob': '06.10.1904', 'nationality': 'POLEN', 'full_name': 'MOZOLEWSKI Kusma'}
# {'surname': 'Napruszewski', 'name': ['Severin'], 'dob': '12.12.1925', 'nationality': 'POLEN', 'full_name': 'NAPRUSZEWSKI Severin'}
# {'surname': 'Pinczewski', 'name': ['Abraham'], 'dob': '13.08.1928', 'nationality': 'POLEN', 'full_name': 'PINCZEWSKI Abraham'}
# {'surname': 'Pinczewski', 'name': ['Aron'], 'dob': '13.08.1928', 'nationality': 'POLEN', 'full_name': 'PINCZEWSKI Aron'}
# {'surname': 'Raszewski', 'name': ['Blanche'], 'dob': '15.05.1934', 'nationality': 'NIEDERLANDE', 'full_name': 'RASZEWSKI Blanche'}
# {'surname': 'Raszewski', 'name': ['Felix'], 'dob': '24.03.1906', 'nationality': 'NIEDERLANDE', 'full_name': 'RASZEWSKI Felix'}
# {'surname': 'Raszewski', 'name': ['Marie'], 'dob': '05.10.1939', 'nationality': 'NIEDERLANDE', 'full_name': 'RASZEWSKI Marie'}
# {'surname': 'Raszewski-Hanower', 'name': ['Denise'], 'dob': '15.08.1909', 'nationality': 'NIEDERLANDE', 'full_name': 'RASZEWSKI-HANOWER Denise'}
# {'surname': 'Smiglewski', 'name': ['Zbigniew'], 'dob': '20.07.1928', 'nationality': 'POLEN', 'full_name': 'SMIGLEWSKI Zbigniew'}
# {'surname': 'Sochaczewski', 'name': ['Michel'], 'dob': '19.06.1933', 'nationality': 'FRANKREICH (POLEN)', 'full_name': 'SOCHACZEWSKI Michel'}
# {'surname': 'Sochaczewski', 'name': ['Samuel'], 'dob': '18.07.1907', 'nationality': 'POLEN', 'full_name': 'SOCHACZEWSKI Samuel'}
# {'surname': 'Staniewski', 'name': ['Zenon'], 'dob': '06.05.1927', 'nationality': 'POLEN', 'full_name': 'STANIEWSKI Zenon'}
# {'surname': 'Szereszewski', 'name': ['Jankiel'], 'dob': '01.10.1884', 'nationality': 'POLEN', 'full_name': 'SZERESZEWSKI Jankiel'}
# {'surname': 'Szereszewski-Rosenfeld', 'name': ['Rosa'], 'dob': '16.07.1882', 'nationality': 'POLEN (RUSSLAND)', 'full_name': 'SZERESZEWSKI-ROSENFELD ROSA'}
# {'surname': 'Szulczewski', 'name': ['Boleslaw'], 'dob': '11.07.1923', 'nationality': 'POLEN', 'full_name': 'SZULCZEWSKI Boleslaw'}
# {'surname': 'Szulczewski', 'name': ['Cesary'], 'dob': '23.07.1908', 'nationality': 'POLEN', 'full_name': 'SZULCZEWSKI Cesary'}
# {'surname': 'Tomaszewski', 'name': ['Henryk'], 'dob': '01.08.1917', 'nationality': 'POLEN', 'full_name': 'TOMASZEWSKI HENRYK'}
# {'surname': 'Tomaszewski', 'name': ['Tadeuz'], 'dob': '01.01.1913', 'nationality': 'POLEN', 'full_name': 'TOMASZEWSKI TADEUZ'}
# {'surname': 'Tomazewski', 'name': ['Mieczyslaw'], 'dob': '06.10.1921', 'nationality': 'POLEN', 'full_name': 'TOMAZEWSKI MIECZYSLAW'}
# {'surname': 'Wachsberg-Wasiliewski', 'name': ['Esther'], 'dob': '20.05.1898', 'nationality': 'STAATENLOS', 'full_name': 'WACHSBERG-WASILIEWSKI Esther'}
# {'surname': 'Weglewski', 'name': ['Kasimierz'], 'dob': '20.02.1925', 'nationality': 'POLEN', 'full_name': 'WEGLEWSKI Kasimierz'}
# {'surname': 'Westreich-Wasiliewski', 'name': ['Reiza'], 'dob': '01.10.1909', 'nationality': 'BELGIEN', 'full_name': 'WESTREICH-WASILIEWSKI Reiza'}
# {'surname': 'Wroblewski', 'name': ['Jeanne'], 'dob': '19.01.1933', 'nationality': 'POLEN', 'full_name': 'WROBLEWSKI JEANNE'}
# {'surname': 'Wroblewski Lazare', 'name': ['Leopold'], 'dob': '12.04.1897', 'nationality': 'POLEN', 'full_name': 'WROBLEWSKI LAZARE LEOPOLD'}
# {'surname': 'Wroblewski Maurice', 'name': ['Louis'], 'dob': '26.11.1931', 'nationality': 'POLEN', 'full_name': 'WROBLEWSKI MAURICE LOUIS'}
# {'surname': 'Wroblewski', 'name': ['Zygmund'], 'dob': '04.06.1919', 'nationality': 'POLEN', 'full_name': 'WROBLEWSKI Zygmund'}
# {'surname': 'Wroblewski-Freidenberg', 'name': ['Ella'], 'dob': '21.07.1898', 'nationality': 'POLEN', 'full_name': 'WROBLEWSKI-FREIDENBERG ELLA'}
# {'surname': 'Zakrzewski', 'name': ['Casimir'], 'dob': '16.09.1915', 'nationality': 'POLEN', 'full_name': 'ZAKRZEWSKI CASIMIR'}
# {'surname': 'Zloczewski', 'name': ['Samuel'], 'dob': '28.09.1930', 'nationality': 'FRANKREICH (POLEN)', 'full_name': 'ZLOCZEWSKI Samuel'}

# %%
import re
from pydantic import BaseModel, Field, validator
from typing import List

def is_valid_date(date_string: str) -> bool:
    date_pattern = r'^\d{1,2}\.\d{1,2}\.\d{4}$'
    if re.match(date_pattern, date_string):
        return True
    return False

class Name(BaseModel):
    first_name: str
    last_name: str

class Person(BaseModel):
    surname: str
    name: List[str]
    dob: str
    nationality: str
    full_name: str  # Add the new field to the Person class

    @validator("dob")
    def validate_dob(cls, dob):
        if not is_valid_date(dob):
            raise ValueError("Invalid date format")
        return dob

    @validator("name", pre=True)
    def split_name(cls, name):
        if not isinstance(name, list):
            raise ValueError("Name must be a list")
        return [n.strip() for n in name]

parsed = parse_document(raw_text)
valid_entries = 0
invalid_entries = 0

for person_data in parsed:
    try:
        person = Person(**person_data)
        valid_entries += 1
    except ValueError as e:
        invalid_entries += 1
        print("Invalid entry:", person_data)
        print("Error:", e)

print(f"Valid entries: {valid_entries}")
print(f"Invalid entries: {invalid_entries}")
# Out:
# Valid entries: 25476
# Invalid entries: 0

# %%
import csv

# Define the header for the CSV file
header = ['Surname', 'Name', 'Date of Birth', 'Nationality', 'Full Name']

# Open the CSV file for writing
with open('WW2_Refugees_Registered_in_Geneva.csv', 'w', encoding='utf-8', newline='') as f:
    writer = csv.writer(f)

    # Write the header to the CSV file
    writer.writerow(header)

    # Write the parsed data to the CSV file
    for person_data in parsed:
        row = [
            person_data['surname'],
            ', '.join(person_data['name']),
            person_data['dob'],
            person_data['nationality'],
            person_data['full_name']
        ]
        writer.writerow(row)

# %%
import pandas as pd

# Create a DataFrame from the parsed data
data = [
    {
        'Surname': person_data['surname'],
        'Name': ', '.join(person_data['name']),
        'Date of Birth': person_data['dob'],
        'Nationality': person_data['nationality'],
        'Full Name': person_data['full_name']
    }
    for person_data in parsed
]
df = pd.DataFrame(data)

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#               Surname                  Name Date of Birth  Nationality  \
# 0           Aardewerk          Jansje-Betty    12.02.1924  NIEDERLANDE
# 1                Abas          Rudolf, ABBE    17.07.1918  NIEDERLANDE
# 2          Abbondanza              Raimondo    17.12.1922      ITALIEN
# 3           Abbondati                 Piero    23.10.1906      ITALIEN
# 4              Abbuhl             Alexandre    16.04.1900      SCHWEIZ
# 5              Abbuhl  Rose-Marie-Madeleine    01.03.1905      SCHWEIZ
# 6    Abd El Kader Ben                 Haous    05.06.1916     ALGERIEN
# 7        Abdeslam Ben              Abdeslam    01.01.1918    UNBEKANNT
# 8          Abdul-Hadi              Nuraldin    15.06.1917    PALASTINA
# 9  Abdul-Hadi-Walther            Marie-Anne    20.03.1918    PALASTINA
#
#                        Full Name
# 0         AARDEWERK Jansje-Betty
# 1                    ABAS Rudolf
# 2            ABBONDANZA Raimondo
# 3                ABBONDATI Piero
# 4               ABBUHL ALEXANDRE
# 5    ABBUHL ROSE-MARIE-MADELEINE
# 6         ABD EL KADER Ben Haous
# 7          ABDESLAM Ben Abdeslam
# 8            ABDUL-HADI NURALDIN
# 9  ABDUL-HADI-WALTHER MARIE-ANNE
